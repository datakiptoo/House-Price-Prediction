# %%
#importing libraries
import pandas as pd
import numpy as np

# %%
#initilaize unseen data
test_house=pd.read_csv('test (1).csv')

# %%
test_house
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub  ...         120        0    NaN  MnPrv
# 1            Lvl    AllPub  ...           0        0    NaN    NaN
# 2            Lvl    AllPub  ...           0        0    NaN  MnPrv
# 3            Lvl    AllPub  ...           0        0    NaN    NaN
# 4            HLS    AllPub  ...         144        0    NaN    NaN
# ...          ...       ...  ...         ...      ...    ...    ...
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0            NaN       0      6    2010        WD         Normal
# 1           Gar2   12500      6    2010        WD         Normal
# 2            NaN       0      3    2010        WD         Normal
# 3            NaN       0      6    2010        WD         Normal
# 4            NaN       0      1    2010        WD         Normal
# ...          ...     ...    ...     ...       ...            ...
# 1454         NaN       0      6    2006        WD         Normal
# 1455         NaN       0      4    2006        WD        Abnorml
# 1456         NaN       0      9    2006        WD        Abnorml
# 1457        Shed     700      7    2006        WD         Normal
# 1458         NaN       0     11    2006        WD         Normal
#
# [1459 rows x 80 columns]

# %%
test_house_data=test_house.copy()

# %%
test_house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
#  17  OverallQual    1459 non-null   int64
#  18  OverallCond    1459 non-null   int64
#  19  YearBuilt      1459 non-null   int64
#  20  YearRemodAdd   1459 non-null   int64
#  21  RoofStyle      1459 non-null   object
#  22  RoofMatl       1459 non-null   object
#  23  Exterior1st    1458 non-null   object
#  24  Exterior2nd    1458 non-null   object
#  25  MasVnrType     565 non-null    object
#  26  MasVnrArea     1444 non-null   float64
#  27  ExterQual      1459 non-null   object
#  28  ExterCond      1459 non-null   object
#  29  Foundation     1459 non-null   object
#  30  BsmtQual       1415 non-null   object
#  31  BsmtCond       1414 non-null   object
#  32  BsmtExposure   1415 non-null   object
#  33  BsmtFinType1   1417 non-null   object
#  34  BsmtFinSF1     1458 non-null   float64
#  35  BsmtFinType2   1417 non-null   object
#  36  BsmtFinSF2     1458 non-null   float64
#  37  BsmtUnfSF      1458 non-null   float64
#  38  TotalBsmtSF    1458 non-null   float64
#  39  Heating        1459 non-null   object
#  40  HeatingQC      1459 non-null   object
#  41  CentralAir     1459 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1459 non-null   int64
#  44  2ndFlrSF       1459 non-null   int64
#  45  LowQualFinSF   1459 non-null   int64
#  46  GrLivArea      1459 non-null   int64
#  47  BsmtFullBath   1457 non-null   float64
#  48  BsmtHalfBath   1457 non-null   float64
#  49  FullBath       1459 non-null   int64
#  50  HalfBath       1459 non-null   int64
#  51  BedroomAbvGr   1459 non-null   int64
#  52  KitchenAbvGr   1459 non-null   int64
#  53  KitchenQual    1458 non-null   object
#  54  TotRmsAbvGrd   1459 non-null   int64
#  55  Functional     1457 non-null   object
#  56  Fireplaces     1459 non-null   int64
#  57  FireplaceQu    729 non-null    object
#  58  GarageType     1383 non-null   object
#  59  GarageYrBlt    1381 non-null   float64
#  60  GarageFinish   1381 non-null   object
#  61  GarageCars     1458 non-null   float64
#  62  GarageArea     1458 non-null   float64
#  63  GarageQual     1381 non-null   object
#  64  GarageCond     1381 non-null   object
#  65  PavedDrive     1459 non-null   object
#  66  WoodDeckSF     1459 non-null   int64
#  67  OpenPorchSF    1459 non-null   int64
#  68  EnclosedPorch  1459 non-null   int64
#  69  3SsnPorch      1459 non-null   int64
#  70  ScreenPorch    1459 non-null   int64
#  71  PoolArea       1459 non-null   int64
#  72  PoolQC         3 non-null      object
#  73  Fence          290 non-null    object
#  74  MiscFeature    51 non-null     object
#  75  MiscVal        1459 non-null   int64
#  76  MoSold         1459 non-null   int64
#  77  YrSold         1459 non-null   int64
#  78  SaleType       1458 non-null   object
#  79  SaleCondition  1459 non-null   object
# dtypes: float64(11), int64(26), object(43)
# memory usage: 912.0+ KB

# %%
test_house_data.describe().T
# Out:
#                 count         mean          std     min      25%     50%  \
# Id             1459.0  2190.000000   421.321334  1461.0  1825.50  2190.0
# MSSubClass     1459.0    57.378341    42.746880    20.0    20.00    50.0
# LotFrontage    1232.0    68.580357    22.376841    21.0    58.00    67.0
# LotArea        1459.0  9819.161069  4955.517327  1470.0  7391.00  9399.0
# OverallQual    1459.0     6.078821     1.436812     1.0     5.00     6.0
# OverallCond    1459.0     5.553804     1.113740     1.0     5.00     5.0
# YearBuilt      1459.0  1971.357779    30.390071  1879.0  1953.00  1973.0
# YearRemodAdd   1459.0  1983.662783    21.130467  1950.0  1963.00  1992.0
# MasVnrArea     1444.0   100.709141   177.625900     0.0     0.00     0.0
# BsmtFinSF1     1458.0   439.203704   455.268042     0.0     0.00   350.5
# BsmtFinSF2     1458.0    52.619342   176.753926     0.0     0.00     0.0
# BsmtUnfSF      1458.0   554.294925   437.260486     0.0   219.25   460.0
# TotalBsmtSF    1458.0  1046.117970   442.898624     0.0   784.00   988.0
# 1stFlrSF       1459.0  1156.534613   398.165820   407.0   873.50  1079.0
# 2ndFlrSF       1459.0   325.967786   420.610226     0.0     0.00     0.0
# LowQualFinSF   1459.0     3.543523    44.043251     0.0     0.00     0.0
# GrLivArea      1459.0  1486.045922   485.566099   407.0  1117.50  1432.0
# BsmtFullBath   1457.0     0.434454     0.530648     0.0     0.00     0.0
# BsmtHalfBath   1457.0     0.065202     0.252468     0.0     0.00     0.0
# FullBath       1459.0     1.570939     0.555190     0.0     1.00     2.0
# HalfBath       1459.0     0.377656     0.503017     0.0     0.00     0.0
# BedroomAbvGr   1459.0     2.854010     0.829788     0.0     2.00     3.0
# KitchenAbvGr   1459.0     1.042495     0.208472     0.0     1.00     1.0
# TotRmsAbvGrd   1459.0     6.385195     1.508895     3.0     5.00     6.0
# Fireplaces     1459.0     0.581220     0.647420     0.0     0.00     0.0
# GarageYrBlt    1381.0  1977.721217    26.431175  1895.0  1959.00  1979.0
# GarageCars     1458.0     1.766118     0.775945     0.0     1.00     2.0
# GarageArea     1458.0   472.768861   217.048611     0.0   318.00   480.0
# WoodDeckSF     1459.0    93.174777   127.744882     0.0     0.00     0.0
# OpenPorchSF    1459.0    48.313914    68.883364     0.0     0.00    28.0
# EnclosedPorch  1459.0    24.243317    67.227765     0.0     0.00     0.0
# 3SsnPorch      1459.0     1.794380    20.207842     0.0     0.00     0.0
# ScreenPorch    1459.0    17.064428    56.609763     0.0     0.00     0.0
# PoolArea       1459.0     1.744345    30.491646     0.0     0.00     0.0
# MiscVal        1459.0    58.167923   630.806978     0.0     0.00     0.0
# MoSold         1459.0     6.104181     2.722432     1.0     4.00     6.0
# YrSold         1459.0  2007.769705     1.301740  2006.0  2007.00  2008.0
#
#                     75%      max
# Id              2554.50   2919.0
# MSSubClass        70.00    190.0
# LotFrontage       80.00    200.0
# LotArea        11517.50  56600.0
# OverallQual        7.00     10.0
# OverallCond        6.00      9.0
# YearBuilt       2001.00   2010.0
# YearRemodAdd    2004.00   2010.0
# MasVnrArea       164.00   1290.0
# BsmtFinSF1       753.50   4010.0
# BsmtFinSF2         0.00   1526.0
# BsmtUnfSF        797.75   2140.0
# TotalBsmtSF     1305.00   5095.0
# 1stFlrSF        1382.50   5095.0
# 2ndFlrSF         676.00   1862.0
# LowQualFinSF       0.00   1064.0
# GrLivArea       1721.00   5095.0
# BsmtFullBath       1.00      3.0
# BsmtHalfBath       0.00      2.0
# FullBath           2.00      4.0
# HalfBath           1.00      2.0
# BedroomAbvGr       3.00      6.0
# KitchenAbvGr       1.00      2.0
# TotRmsAbvGrd       7.00     15.0
# Fireplaces         1.00      4.0
# GarageYrBlt     2002.00   2207.0
# GarageCars         2.00      5.0
# GarageArea       576.00   1488.0
# WoodDeckSF       168.00   1424.0
# OpenPorchSF       72.00    742.0
# EnclosedPorch      0.00   1012.0
# 3SsnPorch          0.00    360.0
# ScreenPorch        0.00    576.0
# PoolArea           0.00    800.0
# MiscVal            0.00  17000.0
# MoSold             8.00     12.0
# YrSold          2009.00   2010.0

# %%
# Display columns with missing values and count of missing values in each column
missing_values = test_house_data.isnull().sum()
missing_columns = missing_values[missing_values > 0]
missing_columns
# Out:
# MSZoning           4
# LotFrontage      227
# Alley           1352
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType       894
# MasVnrArea        15
# BsmtQual          44
# BsmtCond          45
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinSF1         1
# BsmtFinType2      42
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu      730
# GarageType        76
# GarageYrBlt       78
# GarageFinish      78
# GarageCars         1
# GarageArea         1
# GarageQual        78
# GarageCond        78
# PoolQC          1456
# Fence           1169
# MiscFeature     1408
# SaleType           1
# dtype: int64

# %%
# Calculate the threshold for dropping columns
threshold = len(test_house_data) * 0.5  # Half of the total number of rows
test_house_data=test_house_data.dropna(thresh=threshold,axis=1)

# %%
# Display columns with missing values and count of missing values in each column
missing_values = test_house_data.isnull().sum()
missing_columns = missing_values[missing_values > 0]
missing_columns
# Out:
# MSZoning          4
# LotFrontage     227
# Utilities         2
# Exterior1st       1
# Exterior2nd       1
# MasVnrArea       15
# BsmtQual         44
# BsmtCond         45
# BsmtExposure     44
# BsmtFinType1     42
# BsmtFinSF1        1
# BsmtFinType2     42
# BsmtFinSF2        1
# BsmtUnfSF         1
# TotalBsmtSF       1
# BsmtFullBath      2
# BsmtHalfBath      2
# KitchenQual       1
# Functional        2
# GarageType       76
# GarageYrBlt      78
# GarageFinish     78
# GarageCars        1
# GarageArea        1
# GarageQual       78
# GarageCond       78
# SaleType          1
# dtype: int64

# %%
missing_values_columns=['LotFrontage','MasVnrArea','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond' ]
# Get the data types for selected columns
data_types_selected = test_house_data[missing_values_columns].dtypes
data_types_selected
# Out:
# LotFrontage     float64
# MasVnrArea      float64
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# dtype: object

# %%
test_house_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0            Lvl    AllPub    Inside  ...           0             0         0
# 1            Lvl    AllPub    Corner  ...          36             0         0
# 2            Lvl    AllPub    Inside  ...          34             0         0
# 3            Lvl    AllPub    Inside  ...          36             0         0
# 4            HLS    AllPub    Inside  ...          82             0         0
# ...          ...       ...       ...  ...         ...           ...       ...
# 1454         Lvl    AllPub    Inside  ...           0             0         0
# 1455         Lvl    AllPub    Inside  ...          24             0         0
# 1456         Lvl    AllPub    Inside  ...           0             0         0
# 1457         Lvl    AllPub    Inside  ...          32             0         0
# 1458         Lvl    AllPub    Inside  ...          48             0         0
#
#      ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0            120        0       0       6    2010        WD         Normal
# 1              0        0   12500       6    2010        WD         Normal
# 2              0        0       0       3    2010        WD         Normal
# 3              0        0       0       6    2010        WD         Normal
# 4            144        0       0       1    2010        WD         Normal
# ...          ...      ...     ...     ...     ...       ...            ...
# 1454           0        0       0       6    2006        WD         Normal
# 1455           0        0       0       4    2006        WD        Abnorml
# 1456           0        0       0       9    2006        WD        Abnorml
# 1457           0        0     700       7    2006        WD         Normal
# 1458           0        0       0      11    2006        WD         Normal
#
# [1459 rows x 74 columns]

# %%
#LotFrontage
# Calculate the median of the column
median_value =test_house_data['LotFrontage'].median()

# Fill missing values in the column with the calculated median
test_house_data['LotFrontage'].fillna(median_value, inplace=True)

# %%
# Calculate the median of the column
median_value =test_house_data['MasVnrArea'].median()

# Fill missing values in the column with the calculated median
test_house_data['MasVnrArea'].fillna(median_value, inplace=True)

# %%
#Impute with a Default or Sentinel Value
test_house_data['GarageYrBlt'].fillna(pd.Timestamp('1900-01-01'), inplace=True)
test_house_data['GarageYrBlt']=pd.to_datetime(test_house_data['GarageYrBlt'])
test_house_data['GarageYrBlt']=test_house_data['GarageYrBlt'].dt.year
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7260\1509007508.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1900-01-01 00:00:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   test_house_data['GarageYrBlt'].fillna(pd.Timestamp('1900-01-01'), inplace=True)

# %% [markdown]
# Categorical Values: Missing Values

# %%
test_house_data['BsmtQual'].fillna("Unknown",inplace=True,axis=0)
test_house_data['BsmtCond'].fillna("Unknown",inplace=True,axis=0)
test_house_data['BsmtFinType1'].fillna("Unknown",inplace=True,axis=0)
test_house_data['BsmtExposure'].fillna("Unknown",inplace=True,axis=0)
test_house_data['BsmtFinType2'].fillna("Unknown",inplace=True,axis=0)
test_house_data['GarageFinish'].fillna("Unknown",inplace=True,axis=0)
test_house_data['GarageQual'].fillna("Unknown",inplace=True,axis=0)
test_house_data['GarageType'].fillna("Unknown",inplace=True,axis=0)
test_house_data['GarageCond'].fillna("Unknown",inplace=True,axis=0)

# %%
test_house_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0            Lvl    AllPub    Inside  ...           0             0         0
# 1            Lvl    AllPub    Corner  ...          36             0         0
# 2            Lvl    AllPub    Inside  ...          34             0         0
# 3            Lvl    AllPub    Inside  ...          36             0         0
# 4            HLS    AllPub    Inside  ...          82             0         0
# ...          ...       ...       ...  ...         ...           ...       ...
# 1454         Lvl    AllPub    Inside  ...           0             0         0
# 1455         Lvl    AllPub    Inside  ...          24             0         0
# 1456         Lvl    AllPub    Inside  ...           0             0         0
# 1457         Lvl    AllPub    Inside  ...          32             0         0
# 1458         Lvl    AllPub    Inside  ...          48             0         0
#
#      ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0            120        0       0       6    2010        WD         Normal
# 1              0        0   12500       6    2010        WD         Normal
# 2              0        0       0       3    2010        WD         Normal
# 3              0        0       0       6    2010        WD         Normal
# 4            144        0       0       1    2010        WD         Normal
# ...          ...      ...     ...     ...     ...       ...            ...
# 1454           0        0       0       6    2006        WD         Normal
# 1455           0        0       0       4    2006        WD        Abnorml
# 1456           0        0       0       9    2006        WD        Abnorml
# 1457           0        0     700       7    2006        WD         Normal
# 1458           0        0       0      11    2006        WD         Normal
#
# [1459 rows x 74 columns]

# %%
# Display columns with missing values and count of missing values in each column
missing_values = test_house_data.isnull().sum()
missing_columns = missing_values[missing_values > 0]
missing_columns
# Out:
# MSZoning        4
# Utilities       2
# Exterior1st     1
# Exterior2nd     1
# BsmtFinSF1      1
# BsmtFinSF2      1
# BsmtUnfSF       1
# TotalBsmtSF     1
# BsmtFullBath    2
# BsmtHalfBath    2
# KitchenQual     1
# Functional      2
# GarageCars      1
# GarageArea      1
# SaleType        1
# dtype: int64

# %%
test_house_data['SaleType']=test_house_data['SaleType'].fillna(test_house_data['SaleType'].mode()[0])

# %%
mean=test_house_data['GarageArea'].mean()
test_house_data['GarageArea'].fillna(mean,inplace=True)

# %%
mean=test_house_data['GarageCars'].mean()
test_house_data['GarageCars'].fillna(mean,inplace=True)

# %%
test_house_data['Functional']=test_house_data['Functional'].fillna(test_house_data['Functional'].mode()[0])

# %%
test_house_data['KitchenQual']=test_house_data['KitchenQual'].fillna(test_house_data['KitchenQual'].mode()[0])

# %%
mean=test_house_data['BsmtHalfBath'].mean()
test_house_data['BsmtHalfBath'].fillna(mean,inplace=True)

# %%
mean=test_house_data['BsmtFullBath'].mean()
test_house_data['BsmtFullBath'].fillna(mean,inplace=True)

# %%
mean=test_house_data['BsmtUnfSF'].mean()
test_house_data['BsmtUnfSF'].fillna(mean,inplace=True)

# %%
mean=test_house_data['BsmtFinSF2'].mean()
test_house_data['BsmtFinSF2'].fillna(mean,inplace=True)

# %%
mean=test_house_data['BsmtFinSF1'].mean()
test_house_data['BsmtFinSF1'].fillna(mean,inplace=True)

# %%
test_house_data['Exterior2nd']=test_house_data['Exterior2nd'].fillna(test_house_data['Exterior2nd'].mode()[0])

# %%
test_house_data['Exterior1st']=test_house_data['Exterior1st'].fillna(test_house_data['Exterior1st'].mode()[0])

# %%
test_house_data['MSZoning']=test_house_data['MSZoning'].fillna(test_house_data['MSZoning'].mode()[0])

# %%
test_house_data['Utilities']=test_house_data['Utilities'].fillna(test_house_data['Utilities'].mode()[0])

# %%
mean=test_house_data['TotalBsmtSF'].mean()
test_house_data['TotalBsmtSF'].fillna(mean,inplace=True)

# %%
# Display columns with missing values and count of missing values in each column
missing_values = test_house_data.isnull().sum()
missing_columns = missing_values[missing_values > 0]
missing_columns
# Out:
# Series([], dtype: int64)

# %%
test_house_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0            Lvl    AllPub    Inside  ...           0             0         0
# 1            Lvl    AllPub    Corner  ...          36             0         0
# 2            Lvl    AllPub    Inside  ...          34             0         0
# 3            Lvl    AllPub    Inside  ...          36             0         0
# 4            HLS    AllPub    Inside  ...          82             0         0
# ...          ...       ...       ...  ...         ...           ...       ...
# 1454         Lvl    AllPub    Inside  ...           0             0         0
# 1455         Lvl    AllPub    Inside  ...          24             0         0
# 1456         Lvl    AllPub    Inside  ...           0             0         0
# 1457         Lvl    AllPub    Inside  ...          32             0         0
# 1458         Lvl    AllPub    Inside  ...          48             0         0
#
#      ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0            120        0       0       6    2010        WD         Normal
# 1              0        0   12500       6    2010        WD         Normal
# 2              0        0       0       3    2010        WD         Normal
# 3              0        0       0       6    2010        WD         Normal
# 4            144        0       0       1    2010        WD         Normal
# ...          ...      ...     ...     ...     ...       ...            ...
# 1454           0        0       0       6    2006        WD         Normal
# 1455           0        0       0       4    2006        WD        Abnorml
# 1456           0        0       0       9    2006        WD        Abnorml
# 1457           0        0     700       7    2006        WD         Normal
# 1458           0        0       0      11    2006        WD         Normal
#
# [1459 rows x 74 columns]

# %%
#Feature Engineering

#Total Square Footage 
test_house_data['TotalSF'] = test_house_data['1stFlrSF'] + test_house_data['2ndFlrSF']
#Age of the house
test_house_data['HouseAge'] = test_house_data['YrSold'] - test_house_data['YearBuilt']
#Total bathrooms
test_house_data['TotalBath'] = test_house_data['FullBath'] + 0.5 * test_house_data['HalfBath']
#Overall Quality and Condition
test_house_data['OverallQualityCond'] = test_house_data['OverallQual'] * test_house_data['OverallCond']
#Age of garage
test_house_data['GarageAge'] = test_house_data['YrSold'] - test_house_data['GarageYrBlt']
#Presence of a Pool and absence of a Fireplace
test_house_data['HasPool'] = test_house_data['PoolArea'].apply(lambda x: 1 if x > 0 else 0)
test_house_data['HasFireplace'] = test_house_data['Fireplaces'].apply(lambda x: 1 if x > 0 else 0)
#ratio of lot frontage to lot area.
test_house_data['LotRatio'] = test_house_data['LotFrontage'] / test_house_data['LotArea']
#total finished square feet of the basement.
test_house_data['TotalBsmtFinSF'] = test_house_data['BsmtFinSF1'] + test_house_data['BsmtFinSF2']
# total square footage of all porches.
test_house_data['TotalPorchArea'] = test_house_data['WoodDeckSF'] + test_house_data['OpenPorchSF'] + test_house_data['EnclosedPorch'] + test_house_data['3SsnPorch'] + test_house_data['ScreenPorch']
#Create a binary feature 'HasPool' indicating the presence of a pool.
test_house_data['HasPool'] = test_house_data['PoolArea'].apply(lambda x: 1 if x > 0 else 0)

# %%
test_house_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... TotalSF HouseAge TotalBath  \
# 0            Lvl    AllPub    Inside  ...     896       49       1.0
# 1            Lvl    AllPub    Corner  ...    1329       52       1.5
# 2            Lvl    AllPub    Inside  ...    1629       13       2.5
# 3            Lvl    AllPub    Inside  ...    1604       12       2.5
# 4            HLS    AllPub    Inside  ...    1280       18       2.0
# ...          ...       ...       ...  ...     ...      ...       ...
# 1454         Lvl    AllPub    Inside  ...    1092       36       1.5
# 1455         Lvl    AllPub    Inside  ...    1092       36       1.5
# 1456         Lvl    AllPub    Inside  ...    1224       46       1.0
# 1457         Lvl    AllPub    Inside  ...     970       14       1.0
# 1458         Lvl    AllPub    Inside  ...    2000       13       2.5
#
#      OverallQualityCond GarageAge HasPool  HasFireplace  LotRatio  \
# 0                    30        40       0             0  0.006883
# 1                    36        40       0             0  0.005677
# 2                    25        40       0             1  0.005351
# 3                    36        40       0             1  0.007817
# 4                    40        40       0             0  0.008591
# ...                 ...       ...     ...           ...       ...
# 1454                 28       106       0             0  0.010847
# 1455                 20        36       0             0  0.011088
# 1456                 35        36       0             1  0.008000
# 1457                 25       106       0             0  0.005938
# 1458                 35        36       0             1  0.007687
#
#       TotalBsmtFinSF  TotalPorchArea
# 0              612.0             260
# 1              923.0             429
# 2              791.0             246
# 3              602.0             396
# 4              263.0             226
# ...              ...             ...
# 1454             0.0               0
# 1455           252.0              24
# 1456          1224.0             474
# 1457           337.0             112
# 1458           758.0             238
#
# [1459 rows x 84 columns]

# %%
#columns with categorical data
categorical_columns=test_house_data.select_dtypes(include=['object','category'])
categorical_columns.T
# Out:
#                   0        1        2        3        4        5        6     \
# MSZoning            RH       RL       RL       RL       RL       RL       RL
# Street            Pave     Pave     Pave     Pave     Pave     Pave     Pave
# LotShape           Reg      IR1      IR1      IR1      IR1      IR1      IR1
# LandContour        Lvl      Lvl      Lvl      Lvl      HLS      Lvl      Lvl
# Utilities       AllPub   AllPub   AllPub   AllPub   AllPub   AllPub   AllPub
# LotConfig       Inside   Corner   Inside   Inside   Inside   Corner   Inside
# LandSlope          Gtl      Gtl      Gtl      Gtl      Gtl      Gtl      Gtl
# Neighborhood     NAmes    NAmes  Gilbert  Gilbert  StoneBr  Gilbert  Gilbert
# Condition1       Feedr     Norm     Norm     Norm     Norm     Norm     Norm
# Condition2        Norm     Norm     Norm     Norm     Norm     Norm     Norm
# BldgType          1Fam     1Fam     1Fam     1Fam   TwnhsE     1Fam     1Fam
# HouseStyle      1Story   1Story   2Story   2Story   1Story   2Story   1Story
# RoofStyle        Gable      Hip    Gable    Gable    Gable    Gable    Gable
# RoofMatl       CompShg  CompShg  CompShg  CompShg  CompShg  CompShg  CompShg
# Exterior1st    VinylSd  Wd Sdng  VinylSd  VinylSd  HdBoard  HdBoard  HdBoard
# Exterior2nd    VinylSd  Wd Sdng  VinylSd  VinylSd  HdBoard  HdBoard  HdBoard
# ExterQual           TA       TA       TA       TA       Gd       TA       TA
# ExterCond           TA       TA       TA       TA       TA       TA       Gd
# Foundation      CBlock   CBlock    PConc    PConc    PConc    PConc    PConc
# BsmtQual            TA       TA       Gd       TA       Gd       Gd       Gd
# BsmtCond            TA       TA       TA       TA       TA       TA       TA
# BsmtExposure        No       No       No       No       No       No       No
# BsmtFinType1       Rec      ALQ      GLQ      GLQ      ALQ      Unf      ALQ
# BsmtFinType2       LwQ      Unf      Unf      Unf      Unf      Unf      Unf
# Heating           GasA     GasA     GasA     GasA     GasA     GasA     GasA
# HeatingQC           TA       TA       Gd       Ex       Ex       Gd       Ex
# CentralAir           Y        Y        Y        Y        Y        Y        Y
# Electrical       SBrkr    SBrkr    SBrkr    SBrkr    SBrkr    SBrkr    SBrkr
# KitchenQual         TA       Gd       TA       Gd       Gd       TA       TA
# Functional         Typ      Typ      Typ      Typ      Typ      Typ      Typ
# GarageType      Attchd   Attchd   Attchd   Attchd   Attchd   Attchd   Attchd
# GarageFinish       Unf      Unf      Fin      Fin      RFn      Fin      Fin
# GarageQual          TA       TA       TA       TA       TA       TA       TA
# GarageCond          TA       TA       TA       TA       TA       TA       TA
# PavedDrive           Y        Y        Y        Y        Y        Y        Y
# SaleType            WD       WD       WD       WD       WD       WD       WD
# SaleCondition   Normal   Normal   Normal   Normal   Normal   Normal   Normal
#
#                   7        8        9     ...     1449     1450     1451  \
# MSZoning            RL       RL       RL  ...       RM       RM       RL
# Street            Pave     Pave     Pave  ...     Pave     Pave     Pave
# LotShape           IR1      Reg      Reg  ...      Reg      Reg      Reg
# LandContour        Lvl      Lvl      Lvl  ...      Lvl      Lvl      Lvl
# Utilities       AllPub   AllPub   AllPub  ...   AllPub   AllPub   AllPub
# LotConfig       Inside   Inside   Corner  ...   Inside   Inside   Inside
# LandSlope          Gtl      Gtl      Gtl  ...      Gtl      Gtl      Mod
# Neighborhood   Gilbert  Gilbert    NAmes  ...  MeadowV  MeadowV  Mitchel
# Condition1        Norm     Norm     Norm  ...     Norm     Norm     Norm
# Condition2        Norm     Norm     Norm  ...     Norm     Norm     Norm
# BldgType          1Fam     1Fam     1Fam  ...    Twnhs   TwnhsE     1Fam
# HouseStyle      2Story   1Story   1Story  ...   SFoyer   2Story   1Story
# RoofStyle        Gable    Gable    Gable  ...    Gable    Gable    Gable
# RoofMatl       CompShg  CompShg  CompShg  ...  CompShg  CompShg  CompShg
# Exterior1st    VinylSd  HdBoard  Plywood  ...  CemntBd  CemntBd  Plywood
# Exterior2nd    VinylSd  HdBoard  Plywood  ...  CmentBd  CmentBd  Plywood
# ExterQual           TA       TA       TA  ...       TA       TA       TA
# ExterCond           TA       TA       TA  ...       TA       TA       TA
# Foundation       PConc    PConc   CBlock  ...   CBlock   CBlock    PConc
# BsmtQual            Gd       Gd       TA  ...       Gd       TA       TA
# BsmtCond            TA       TA       TA  ...       TA       TA       TA
# BsmtExposure        No       Gd       No  ...       Av       No       Av
# BsmtFinType1       Unf      GLQ      ALQ  ...      GLQ      Rec      Rec
# BsmtFinType2       Unf      Unf      Rec  ...      Unf      Unf      BLQ
# Heating           GasA     GasA     GasA  ...     GasA     GasA     GasA
# HeatingQC           Gd       Gd       TA  ...       TA       TA       Fa
# CentralAir           Y        Y        Y  ...        Y        Y        Y
# Electrical       SBrkr    SBrkr    SBrkr  ...    SBrkr    SBrkr    SBrkr
# KitchenQual         TA       Gd       TA  ...       TA       TA       TA
# Functional         Typ      Typ      Typ  ...      Typ      Typ      Typ
# GarageType      Attchd   Attchd   Attchd  ...  Unknown   Attchd   Attchd
# GarageFinish       Fin      Unf      Fin  ...  Unknown      Unf      RFn
# GarageQual          TA       TA       TA  ...  Unknown       TA       TA
# GarageCond          TA       TA       TA  ...  Unknown       Fa       TA
# PavedDrive           Y        Y        Y  ...        Y        Y        Y
# SaleType            WD       WD       WD  ...       WD       WD       WD
# SaleCondition   Normal   Normal   Normal  ...   Normal   Normal   Normal
#
#                   1452     1453     1454     1455     1456     1457     1458
# MSZoning            RM       RM       RM       RM       RL       RL       RL
# Street            Pave     Pave     Pave     Pave     Pave     Pave     Pave
# LotShape           Reg      Reg      Reg      Reg      Reg      Reg      Reg
# LandContour        Lvl      Lvl      Lvl      Lvl      Lvl      Lvl      Lvl
# Utilities       AllPub   AllPub   AllPub   AllPub   AllPub   AllPub   AllPub
# LotConfig       Inside   Inside   Inside   Inside   Inside   Inside   Inside
# LandSlope          Gtl      Gtl      Gtl      Gtl      Gtl      Gtl      Mod
# Neighborhood   MeadowV  MeadowV  MeadowV  MeadowV  Mitchel  Mitchel  Mitchel
# Condition1        Norm     Norm     Norm     Norm     Norm     Norm     Norm
# Condition2        Norm     Norm     Norm     Norm     Norm     Norm     Norm
# BldgType         Twnhs    Twnhs    Twnhs   TwnhsE     1Fam     1Fam     1Fam
# HouseStyle      2Story   2Story   2Story   2Story   1Story   SFoyer   2Story
# RoofStyle        Gable    Gable    Gable    Gable    Gable    Gable    Gable
# RoofMatl       CompShg  CompShg  CompShg  CompShg  CompShg  CompShg  CompShg
# Exterior1st    CemntBd  CemntBd  CemntBd  CemntBd  VinylSd  HdBoard  HdBoard
# Exterior2nd    CmentBd  CmentBd  CmentBd  CmentBd  VinylSd  Wd Shng  HdBoard
# ExterQual           TA       TA       TA       TA       TA       TA       TA
# ExterCond           TA       TA       TA       TA       TA       TA       TA
# Foundation      CBlock   CBlock   CBlock   CBlock   CBlock    PConc    PConc
# BsmtQual            TA       TA       TA       TA       TA       Gd       Gd
# BsmtCond            TA       TA       TA       TA       TA       TA       TA
# BsmtExposure        No       No       No       No       No       Av       Av
# BsmtFinType1       Rec      Unf      Unf      Rec      ALQ      GLQ      LwQ
# BsmtFinType2       Unf      Unf      Unf      Unf      Unf      Unf      Unf
# Heating           GasA     GasA     GasA     GasA     GasA     GasA     GasA
# HeatingQC           TA       TA       Gd       TA       Ex       TA       Ex
# CentralAir           Y        Y        Y        Y        Y        Y        Y
# Electrical       SBrkr    SBrkr    SBrkr    SBrkr    SBrkr    SBrkr    SBrkr
# KitchenQual         TA       TA       TA       TA       TA       TA       TA
# Functional         Typ      Typ      Typ      Typ      Typ      Typ      Typ
# GarageType     CarPort  Unknown  Unknown  CarPort   Detchd  Unknown   Attchd
# GarageFinish       Unf  Unknown  Unknown      Unf      Unf  Unknown      Fin
# GarageQual          TA  Unknown  Unknown       TA       TA  Unknown       TA
# GarageCond          TA  Unknown  Unknown       TA       TA  Unknown       TA
# PavedDrive           Y        Y        Y        Y        Y        Y        Y
# SaleType            WD       WD       WD       WD       WD       WD       WD
# SaleCondition  Abnorml   Normal   Normal  Abnorml  Abnorml   Normal   Normal
#
# [37 rows x 1459 columns]

# %%
test_house_data['Condition2'].value_counts()
# Out:
# Condition2
# Norm      1444
# Feedr        7
# PosA         3
# Artery       3
# PosN         2
# Name: count, dtype: int64

# %%
# Use %store -r to retrieve the stored variable
# %store -r house_data
# %store -r house_data_encoded

# %%
# Assuming 'Condition2' is the categorical column in both training and validation datasets
train_unique_categories = set(house_data['Condition2'].unique())
test_unique_categories = set(test_house_data['Condition2'].unique())

# Find non-unique categories
non_unique_categories_train = train_unique_categories - test_unique_categories
non_unique_categories_test = test_unique_categories - train_unique_categories

print("Non-unique categories in training dataset:", non_unique_categories_train)
print("Non-unique categories in validation dataset:", non_unique_categories_test)
# Out:
# Non-unique categories in training dataset: {'RRAn', 'RRAe', 'RRNn'}
# Non-unique categories in validation dataset: set()

# %%
# Assuming 'Condition2' is the categorical column in both training and validation datasets
common_categories = set(house_data['Condition2'].unique()) & set(test_house_data['Condition2'].unique())

# Define a default category (e.g., 'Other')
default_category = 'Other'

# Include non-unique categories in test data
test_house_data['Condition2'] = test_house_data['Condition2'].apply(lambda x: x if x in common_categories.union(non_unique_categories_train) else default_category)

# %%
common_categories
# Out:
# {'Artery', 'Feedr', 'Norm', 'PosA', 'PosN'}

# %%
test_house_data['Condition2'].value_counts()
# Out:
# Condition2
# Norm      1444
# Feedr        7
# PosA         3
# Artery       3
# PosN         2
# Name: count, dtype: int64

# %%
test_data_encoded=pd.get_dummies(test_house_data,categorical_columns, dummy_na=False, drop_first=True)
test_data_encoded=test_data_encoded.reindex(columns=house_data_encoded.columns, fill_value=0)  # Align columns with training data
#Drop the original categorical column from the test data
test_data_encoded = test_house_data.drop('Category', axis=1).join(test_data_encoded)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 test_data_encoded=pd.get_dummies(test_house_data,categorical_columns, dummy_na=False, drop_first=True)
#       2 test_data_encoded=test_data_encoded.reindex(columns=house_data_encoded.columns, fill_value=0)  # Align columns with training data
#       3 #Drop the original categorical column from the test data
#
# File c:\Users\hp\anaconda3\envs\myenv\lib\site-packages\pandas\core\reshape\encoding.py:177, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     170             len_msg = (
#     171                 f"Length of '{name}' ({len(item)}) did not match the "
#     172                 "length of the columns being encoded "
#     173                 f"({data_to_encode.shape[1]})."
#     174             )
#     175             raise ValueError(len_msg)
# --> 177 check_len(prefix, "prefix")
#     178 check_len(prefix_sep, "prefix_sep")
#     180 if isinstance(prefix, str):
#
# File c:\Users\hp\anaconda3\envs\myenv\lib\site-packages\pandas\core\reshape\encoding.py:175, in get_dummies.<locals>.check_len(item, name)
#     169 if not len(item) == data_to_encode.shape[1]:
#     170     len_msg = (
#     171         f"Length of '{name}' ({len(item)}) did not match the "
#     172         "length of the columns being encoded "
#     173         f"({data_to_encode.shape[1]})."
#     174     )
# --> 175     raise ValueError(len_msg)
#
# ValueError: Length of 'prefix' (1459) did not match the length of the columns being encoded (37).

# %%
# Dummy encoding the categorical columns
dummy_variables = pd.get_dummies(,dummy_na=False, drop_first=True)
# Drop the original categorical columns from the DataFrame
test_data_encoded = test_house_data.drop(categorical_columns.columns, axis=1)
# Concatenate the dummy-encoded columns with the original DataFrame
test_data_encoded = pd.concat([test_data_encoded, dummy_variables], axis=1)

# %%
test_data_encoded
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1461          20         80.0    11622            5            6
# 1     1462          20         81.0    14267            6            6
# 2     1463          60         74.0    13830            5            5
# 3     1464          60         78.0     9978            6            6
# 4     1465         120         43.0     5005            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1454  2915         160         21.0     1936            4            7
# 1455  2916         160         21.0     1894            4            5
# 1456  2917          20        160.0    20000            5            7
# 1457  2918          85         62.0    10441            5            5
# 1458  2919          60         74.0     9627            7            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  \
# 0          1961          1961         0.0       468.0  ...           False
# 1          1958          1958       108.0       923.0  ...           False
# 2          1997          1998         0.0       791.0  ...           False
# 3          1998          1998        20.0       602.0  ...           False
# 4          1992          1992         0.0       263.0  ...           False
# ...         ...           ...         ...         ...  ...             ...
# 1454       1970          1970         0.0         0.0  ...           False
# 1455       1970          1970         0.0       252.0  ...           False
# 1456       1960          1996         0.0      1224.0  ...           False
# 1457       1992          1992         0.0       337.0  ...           False
# 1458       1993          1994        94.0       758.0  ...           False
#
#       SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0              False         False         False         True
# 1              False         False         False         True
# 2              False         False         False         True
# 3              False         False         False         True
# 4              False         False         False         True
# ...              ...           ...           ...          ...
# 1454           False         False         False         True
# 1455           False         False         False         True
# 1456           False         False         False         True
# 1457           False         False         False         True
# 1458           False         False         False         True
#
#       SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0                     False                 False                 False
# 1                     False                 False                 False
# 2                     False                 False                 False
# 3                     False                 False                 False
# 4                     False                 False                 False
# ...                     ...                   ...                   ...
# 1454                  False                 False                 False
# 1455                  False                 False                 False
# 1456                  False                 False                 False
# 1457                  False                 False                 False
# 1458                  False                 False                 False
#
#       SaleCondition_Normal  SaleCondition_Partial
# 0                     True                  False
# 1                     True                  False
# 2                     True                  False
# 3                     True                  False
# 4                     True                  False
# ...                    ...                    ...
# 1454                  True                  False
# 1455                 False                  False
# 1456                 False                  False
# 1457                  True                  False
# 1458                  True                  False
#
# [1459 rows x 233 columns]

# %%
# Selecting only the numerical columns
numerical_columns =test_data_encoded.select_dtypes(include=['number']).columns.tolist()
items_to_remove=['YrSold','MoSold','GarageYrBlt','YearBuilt','YearRemodAdd','Id']
# Removing multiple items using list comprehension
numerical_columns = [col for col in numerical_columns if col not in items_to_remove]

# %%
columns_to_remove=['YrSold','GarageYrBlt','PoolArea',
                   'WoodDeckSF','OpenPorchSF','EnclosedPorch',
                   '3SsnPorch','ScreenPorch','BsmtFinSF1',
                   'BsmtFinSF2','LotFrontage','LotArea',
                   'Fireplaces','PoolArea','OverallQual',
                   'OverallCond','FullBath','HalfBath',
                   'YrSold','YearBuilt','1stFlrSF',
                   '2ndFlrSF','Id'
]

# %%
test = test_data_encoded.drop(columns=columns_to_remove)
test
# Out:
#       MSSubClass  YearRemodAdd  MasVnrArea  BsmtUnfSF  TotalBsmtSF  \
# 0             20          1961         0.0      270.0        882.0
# 1             20          1958       108.0      406.0       1329.0
# 2             60          1998         0.0      137.0        928.0
# 3             60          1998        20.0      324.0        926.0
# 4            120          1992         0.0     1017.0       1280.0
# ...          ...           ...         ...        ...          ...
# 1454         160          1970         0.0      546.0        546.0
# 1455         160          1970         0.0      294.0        546.0
# 1456          20          1996         0.0        0.0       1224.0
# 1457          85          1992         0.0      575.0        912.0
# 1458          60          1994        94.0      238.0        996.0
#
#       LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  BedroomAbvGr  ...  \
# 0                0        896           0.0           0.0             2  ...
# 1                0       1329           0.0           0.0             3  ...
# 2                0       1629           0.0           0.0             3  ...
# 3                0       1604           0.0           0.0             3  ...
# 4                0       1280           0.0           0.0             2  ...
# ...            ...        ...           ...           ...           ...  ...
# 1454             0       1092           0.0           0.0             3  ...
# 1455             0       1092           0.0           0.0             3  ...
# 1456             0       1224           1.0           0.0             4  ...
# 1457             0        970           0.0           1.0             3  ...
# 1458             0       2000           0.0           0.0             3  ...
#
#       SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0              False           False         False         False         True
# 1              False           False         False         False         True
# 2              False           False         False         False         True
# 3              False           False         False         False         True
# 4              False           False         False         False         True
# ...              ...             ...           ...           ...          ...
# 1454           False           False         False         False         True
# 1455           False           False         False         False         True
# 1456           False           False         False         False         True
# 1457           False           False         False         False         True
# 1458           False           False         False         False         True
#
#       SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0                     False                 False                 False
# 1                     False                 False                 False
# 2                     False                 False                 False
# 3                     False                 False                 False
# 4                     False                 False                 False
# ...                     ...                   ...                   ...
# 1454                  False                 False                 False
# 1455                  False                 False                 False
# 1456                  False                 False                 False
# 1457                  False                 False                 False
# 1458                  False                 False                 False
#
#       SaleCondition_Normal  SaleCondition_Partial
# 0                     True                  False
# 1                     True                  False
# 2                     True                  False
# 3                     True                  False
# 4                     True                  False
# ...                    ...                    ...
# 1454                  True                  False
# 1455                 False                  False
# 1456                 False                  False
# 1457                  True                  False
# 1458                  True                  False
#
# [1459 rows x 212 columns]

# %%
from sklearn.preprocessing import StandardScaler
import joblib
scaler=joblib.load('trained_scaler.joblib')

# %%
unseen_data_scaled=scaler.transform(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 unseen_data_scaled=scaler.transform(test)
#
# File c:\Users\hp\anaconda3\envs\myenv\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\Users\hp\anaconda3\envs\myenv\lib\site-packages\sklearn\preprocessing\_data.py:992, in StandardScaler.transform(self, X, copy)
#     989 check_is_fitted(self)
#     991 copy = copy if copy is not None else self.copy
# --> 992 X = self._validate_data(
#     993     X,
#     994     reset=False,
#     995     accept_sparse="csr",
#     996     copy=copy,
#     997     dtype=FLOAT_DTYPES,
#     998     force_all_finite="allow-nan",
#     999 )
#    1001 if sparse.issparse(X):
#    1002     if self.with_mean:
#
# File c:\Users\hp\anaconda3\envs\myenv\lib\site-packages\sklearn\base.py:548, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     483 def _validate_data(
#     484     self,
#     485     X="no_validation",
#    (...)
#     489     **check_params,
#     490 ):
#     491     """Validate input data and set or check the `n_features_in_` attribute.
#     492
#     493     Parameters
#    (...)
#     546         validated.
#     547     """
# --> 548     self._check_feature_names(X, reset=reset)
#     550     if y is None and self._get_tags()["requires_y"]:
#     551         raise ValueError(
#     552             f"This {self.__class__.__name__} estimator "
#     553             "requires y to be passed, but the target y is None."
#     554         )
#
# File c:\Users\hp\anaconda3\envs\myenv\lib\site-packages\sklearn\base.py:481, in BaseEstimator._check_feature_names(self, X, reset)
#     476 if not missing_names and not unexpected_names:
#     477     message += (
#     478         "Feature names must be in the same order as they were in fit.\n"
#     479     )
# --> 481 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - Condition2_RRAe
# - Condition2_RRAn
# - Condition2_RRNn
# - Electrical_Mix
# - Exterior1st_ImStucc
# - ...

# %%
|
